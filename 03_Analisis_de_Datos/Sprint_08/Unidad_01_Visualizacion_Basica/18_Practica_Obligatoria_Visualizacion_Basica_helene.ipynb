# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: VISUALIZACION BASICA

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en un único ejercicio de construcción de gráficas. Descarga este notebook en tu ordenador y trabaja en local. Ten en cuenta que tendrás que descar los directorios de imágenes y datos adicionales, si los hubiera.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## #1

# %% [markdown]
# ### #1.1

# %% [markdown]
# Carga el dataset de casas de California que está en la ruta "./data/california_cities.csv". Muestra parte de su contenido y su descripción. Deshazte de las filas con nulos.

# %%
data= pd.read_csv("./data/california_cities.csv")
data.drop(columns=["Unnamed: 0"], inplace=True)

# %%
data.head(5)
# Out:
#           city       latd       longd  elevation_m  elevation_ft  \
# 0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2      Alameda  37.756111 -122.274444          NaN          33.0
# 3       Albany  37.886944 -122.297778          NaN          43.0
# 4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
#    area_total_km2  area_land_km2  area_water_km2  area_water_percent
# ...

# %%
data.describe()
# Out:
#              latd       longd  elevation_m  elevation_ft  population_total  \
# count  482.000000  482.000000   434.000000    470.000000      4.820000e+02
# mean    36.095088 -119.837714   180.416705    567.168723      6.489493e+04
# std      2.298006    2.147676   309.531825   1001.265722      2.032041e+05
# min     32.578333 -124.263333   -34.000000   -180.000000      1.000000e+00
# 25%     33.977292 -121.954931    22.000000     69.000000      1.090200e+04
# 50%     36.204722 -119.708611    67.000000    200.000000      2.905750e+04
# 75%     37.886667 -117.977292   173.500000    515.000000      6.646650e+04
# max     41.965000 -114.596389  2402.000000   7880.000000      3.884307e+06
#
#        area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  area_total_km2  \
# count        480.000000       482.000000        481.000000      477.000000
# mean          18.442183        16.840981          1.589630       46.753283
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   city                482 non-null    object
#  1   latd                482 non-null    float64
#  2   longd               482 non-null    float64
#  3   elevation_m         434 non-null    float64
#  4   elevation_ft        470 non-null    float64
#  5   population_total    482 non-null    int64
#  6   area_total_sq_mi    480 non-null    float64
#  7   area_land_sq_mi     482 non-null    float64
#  8   area_water_sq_mi    481 non-null    float64
#  9   area_total_km2      477 non-null    float64
#  10  area_land_km2       478 non-null    float64
#  11  area_water_km2      478 non-null    float64
#  12  area_water_percent  477 non-null    float64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 49.1+ KB

# %% [markdown]
# ### #1.2
#
# Recrea la siguiente figura, para ello construye en apartados separados cada gráfico y luego haz un apartado en el que se junten los cuatro. Las figuras son:
# 1. Las ciudades más pobladas, con los numeros de las poblaciones (tendrás que usar texto y recordar que para centrarlos se necesita poner el argumento `ha` a "center"). (Colores: azul, gris, aceituna, marrón, con trasparencia)
# 2. Histograma del área total ocupada por las ciudades. (50 bins, fuente = "Bradley Hand itc", tamaño 18, color azul acero)
# 3. El scatter de área de agua de un ciudad con su poblacion.
# 4. El boxplot de la altura de las ciudades.

# %%
dict={"size":10, "family":"Times New Roman", "color": "black"}
x= data["area_water_km2"]
y= data["population_total"]
plt.scatter(x, y, c="g", alpha=0.5)
plt.title("Población por kilometro cuadrado de agua", fontdict=dict)
plt.xlabel("Area de agua en la ciuadad (km2)",size=8)
plt.ylabel("Población (miles de habitantes)",size=8)
props_flecha = {"arrowstyle": "->", 
                "connectionstyle": "angle3"}
plt.annotate("Outliers" ,(85,0),  arrowprops = props_flecha);

#plt.text(data["population_total"].max(), data["area_water_km2"].max(),"Outliers");

# %%
plt.hist(data["area_total_km2"], bins=50, color= "steelblue", alpha= 0.7)
plt.ylabel("Número de ciudades")
plt.xlabel("Superficie")
plt.legend("Hist Area")

# %%
data.loc[data["population_total"]== data["population_total"].max()]
# Out:
#            city   latd   longd  elevation_m  elevation_ft  population_total  \
# 239  LosAngeles  34.05 -118.25         71.0           2.0           3884307
#
#      area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  area_total_km2  \
# 239             503.0            469.0              34.0          1302.0
#
#      area_land_km2  area_water_km2  area_water_percent
# 239         1214.0            88.0                 6.7

# %%
ciudades = data.loc[data["city"]=="SanDiego"or"LosAngeles"]
ciudades
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23780\1489929969.py in ?()
# ----> 1 ciudades = data.loc[data["city"]=="SanDiego"or"LosAngeles"]
#       2 ciudades
#
# c:\Users\Usuario\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
ciudades = data.loc[data["city"]=="LosAngeles","SanDiego"]
plt.bar(ciudades,ciudades["population_total"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 ciudades = data.loc[data["city"]=="LosAngeles"]
# ----> 2 plt.bar(ciudades,ciudades["population_total"])
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:2979, in bar(x, height, width, bottom, align, data, **kwargs)
#    2968 @_copy_docstring_and_deprecators(Axes.bar)
#    2969 def bar(
#    2970     x: float | ArrayLike,
#    (...)   2977     **kwargs,
#    2978 ) -> BarContainer:
# -> 2979     return gca().bar(
#    2980         x,
#    2981         height,
#    2982         width=width,
#    2983         bottom=bottom,
#    2984         align=align,
#    2985         **({"data": data} if data is not None else {}),
#    2986         **kwargs,
#    2987     )
#
# ...

# %%
data.plot.box(column="elevation_m", vert=False, color= "r")
dict={"size":10, "family":"Times New Roman", "color": "black"}
plt.title("Diagrama de caja de la Altitud de las ciuadades de California", fontdict= dict);

# %%
categorias = data.city.value_counts().index.to_list()
frecuencias = data.population.value_counts().to_list()
frec_relativas = (df_titanic.who.value_counts(normalize = True) * 100).to_list()
fig,ax = plt.subplots(1,2, figsize = (4.5,3))
fig.subplots_adjust(wspace = 0.5)
ax1=plt.bar(categorias, frecuencias)
plt.set_title("Ciudades")
plt.set_xlabel("Ciudades")
plt.set_ylabel("Habitantes")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22312\305236885.py in ?()
#       1 categorias = data.city.value_counts().index.to_list()
# ----> 2 frecuencias = data.population.value_counts().to_list()
#       3 frec_relativas = (df_titanic.who.value_counts(normalize = True) * 100).to_list()
#       4 fig,ax = plt.subplots(1,2, figsize = (4.5,3))
#       5 fig.subplots_adjust(wspace = 0.5)
#
# c:\Users\Usuario\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'population'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)    360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'str' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 data.loc[data["city"] == "LosAngeles"] & data.loc[data["city"] == "SanDiego"]
#
# ...

# %%
data.groupby("city")["population_total"].max().sort_values()
# Out:
# city
# Pomona                1
# Vernon              112
# AmadorCity          185
# Industry            219
# SandCity            334
#                  ...
# Fresno           509039
# SanFrancisco     837442
# SanJose         1000536
# SanDiego        1345895
# LosAngeles      3884307
# Name: population_total, Length: 482, dtype: int64

# %% [markdown]
# ![figura_ejempo.png](attachment:figura_ejempo.png)

# %%
fig,ax= plt.subplots(2,2)
ax[0,2].hist(data["area_total_km2"], bins=50, color= "steelblue", alpha= 0.7)
plt.ylabel =("Número de ciudades")
plt.xlabel=("Superficie")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[101], line 2
#       1 fig,ax= plt.subplots(2,2)
# ----> 2 ax[0,2].hist(data["area_total_km2"], bins=50, color= "steelblue", alpha= 0.7)
#       3 plt.ylabel =("Número de ciudades")
#       4 plt.xlabel=("Superficie")
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
data["elevation_m"]
# Out:
# 0       875.0
# 1       281.0
# 2         NaN
# 3         NaN
# 4       150.0
#         ...
# 477      30.0
# 478     787.0
# 479      18.0
# 480     798.0
# 481    1027.0
# Name: elevation_m, Length: 482, dtype: float64

# %%
fig = plt.figure(figsize=(50,30))
plt.subplots(2,2)

plt.subplot(2, 2, 1) # filas, columnas, indice
plt.bar(data["city"],data["population_total"]);

plt.subplot(2, 2, 2) # filas, columnas, indice
plt.hist(data["area_total_km2"], bins=50, color= "steelblue", alpha= 0.7)
plt.ylabel("Número de ciudades");
plt.xlabel("Superficie");
plt.legend("Hist");


plt.subplot(2, 2,3 ) # filas, columnas, indice
dict={"size":10, "family":"Times New Roman", "color": "black"}
x= data["area_water_km2"]
y= data["population_total"]
plt.scatter(x, y, c="g", alpha=0.5)
plt.title("Población por kilometro cuadrado de agua", fontdict=dict)
plt.xlabel("Area de agua en la ciuadad (km2)", size=8)
plt.ylabel("Población (miles de habitantes)",size=8)
props_flecha = {"arrowstyle": "->", 
               "connectionstyle": "angle3"}
plt.annotate("Outliers" ,(85,0),  arrowprops = props_flecha);

plt.subplot(2, 2, 4) # filas, columnas, indice
dict={"size":10, "family":"Times New Roman", "color": "black"}
plt.boxplot(x= data["elevation_m"], vert= False)
plt.title("Diagrama de caja de la Altitud de las ciuadades de California", fontdict= dict);

# %% [markdown]
# ### #1.3
#
# Graba la figura en un archivo y sube el archivo a tu repo personal también.

# %%
fig.savefig("./img/my_figue.png")
